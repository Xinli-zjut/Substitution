# %%
const sol722 = Vector{Tuple{Matrix{Rational{Int}}, Matrix{Rational{Int}}, Matrix{Rational{Int}}}}(undef, 23);

# %%
# -------- i = 1 --------
U1 = Rational{Int}[
    0 0 0
    0 0 0
    0 0 1
]

V1 = Rational{Int}[
    1 0 0
    1 0 0
    -1 0 0
]

W1 = Rational{Int}[
    1 -1 -1
    0 0 0
    0 0 0
]

sol722[1] = (U1, V1, W1)

# -------- i = 2 --------
U2 = Rational{Int}[
    0 0 0
    0 1 0
    0 0 1
]

V2 = Rational{Int}[
    0 0 0
    1 0 0
    0 -1 0
]

W2 = Rational{Int}[
    0 1 0
    0 0 -1
    0 0 0
]

sol722[2] = (U2, V2, W2)

# -------- i = 3 --------
U3 = Rational{Int}[
    1 1 0
    0 0 0
    1 1 0
]

V3 = Rational{Int}[
    0 0 0
    0 0 1
    0 0 0
]

W3 = Rational{Int}[
    0 0 0
    -1 0 0
    1 0 0
]

sol722[3] = (U3, V3, W3)

# -------- i = 4 --------
U4 = Rational{Int}[
    -1 0 0
    1 0 0
    0 0 0
]

V4 = Rational{Int}[
    0 1 1
    0 0 0
    0 0 0
]

W4 = Rational{Int}[
    0 0 0
    0 0 0
    0 1 0
]

sol722[4] = (U4, V4, W4)

# -------- i = 5 --------
U5 = Rational{Int}[
    0 0 0
    0 0 0
    1 1 0
]

V5 = Rational{Int}[
    0 1 0
    0 0 0
    0 0 0
]

W5 = Rational{Int}[
    0 0 0
    -1 0 1
    1 0 -1
]

sol722[5] = (U5, V5, W5)

# -------- i = 6 --------
U6 = Rational{Int}[
    0 0 0
    0 1 1
    0 0 0
]

V6 = Rational{Int}[
    0 0 0
    0 0 0
    0 1 0
]

W6 = Rational{Int}[
    0 1 0
    1 1 0
    0 0 0
]

sol722[6] = (U6, V6, W6)

# -------- i = 7 --------
U7 = Rational{Int}[
    0 0 0
    1 0 0
    0 0 1
]

V7 = Rational{Int}[
    1 0 0
    0 0 0
    0 0 0
]

W7 = Rational{Int}[
    0 1 0
    0 0 0
    0 0 0
]

sol722[7] = (U7, V7, W7)

# -------- i = 8 --------
U8 = Rational{Int}[
    0 0 0
    0 0 0
    1 0 1
]

V8 = Rational{Int}[
    1 0 0
    0 0 0
    0 0 0
]

W8 = Rational{Int}[
    0 0 1
    0 0 0
    0 0 -1
]

sol722[8] = (U8, V8, W8)

# -------- i = 9 --------
U9 = Rational{Int}[
    0 0 0
    0 1 0
    0 0 0
]

V9 = Rational{Int}[
    0 -1 0
    0 1 0
    0 -1 0
]

W9 = Rational{Int}[
    0 0 0
    0 1 1
    0 -1 0
]

sol722[9] = (U9, V9, W9)

# -------- i = 10 --------
U10 = Rational{Int}[
    0 0 0
    0 1 0
    0 -1 0
]

V10 = Rational{Int}[
    0 1 0
    1 -1 0
    0 0 0
]

W10 = Rational{Int}[
    0 0 0
    0 0 1
    0 0 0
]

sol722[10] = (U10, V10, W10)

# -------- i = 11 --------
U11 = Rational{Int}[
    0 0 0
    0 0 0
    0 1 1
]

V11 = Rational{Int}[
    0 0 0
    1 0 0
    0 0 0
]

W11 = Rational{Int}[
    0 0 1
    0 0 1
    0 0 0
]

sol722[11] = (U11, V11, W11)

# -------- i = 12 --------
U12 = Rational{Int}[
    0 0 -1
    0 1 1
    0 0 0
]

V12 = Rational{Int}[
    0 0 0
    0 1 1
    0 -1 0
]

W12 = Rational{Int}[
    0 0 0
    1 0 0
    0 1 0
]

sol722[12] = (U12, V12, W12)

# -------- i = 13 --------
U13 = Rational{Int}[
    0 0 1
    0 0 0
    0 0 1
]

V13 = Rational{Int}[
    0 0 0
    0 0 0
    1 0 1
]

W13 = Rational{Int}[
    1 0 0
    0 0 0
    0 0 0
]

sol722[13] = (U13, V13, W13)

# -------- i = 14 --------
U14 = Rational{Int}[
    1 0 0
    0 0 0
    1 0 0
]

V14 = Rational{Int}[
    1 0 1
    0 0 -1
    0 0 0
]

W14 = Rational{Int}[
    0 0 0
    0 0 0
    0 0 1
]

sol722[14] = (U14, V14, W14)

# -------- i = 15 --------
U15 = Rational{Int}[
    1 0 0
    0 0 0
    0 0 -1
]

V15 = Rational{Int}[
    1 0 0
    0 0 0
    0 0 1
]

W15 = Rational{Int}[
    1 0 0
    0 0 0
    0 0 -1
]

sol722[15] = (U15, V15, W15)

# -------- i = 16 --------
U16 = Rational{Int}[
    0 0 1
    0 0 -1
    0 0 0
]

V16 = Rational{Int}[
    0 0 0
    0 1 1
    0 -1 -1
]

W16 = Rational{Int}[
    0 0 0
    0 0 0
    0 1 0
]

sol722[16] = (U16, V16, W16)

# -------- i = 17 --------
U17 = Rational{Int}[
    0 1 1
    0 -1 -1
    0 0 0
]

V17 = Rational{Int}[
    0 0 0
    0 1 1
    0 0 0
]

W17 = Rational{Int}[
    0 0 0
    1 0 0
    0 0 0
]

sol722[17] = (U17, V17, W17)

# -------- i = 18 --------
U18 = Rational{Int}[
    0 0 0
    0 0 1
    0 0 -1
]

V18 = Rational{Int}[
    0 0 0
    0 0 0
    1 -1 0
]

W18 = Rational{Int}[
    0 1 0
    0 0 0
    0 0 0
]

sol722[18] = (U18, V18, W18)

# -------- i = 19 --------
U19 = Rational{Int}[
    1 0 0
    0 0 0
    1 1 0
]

V19 = Rational{Int}[
    0 1 0
    0 0 1
    0 0 0
]

W19 = Rational{Int}[
    0 0 0
    1 0 0
    -1 0 1
]

sol722[19] = (U19, V19, W19)

# -------- i = 20 --------
U20 = Rational{Int}[
    1 0 1
    0 0 0
    0 0 0
]

V20 = Rational{Int}[
    0 0 0
    0 0 0
    0 0 1
]

W20 = Rational{Int}[
    -1 0 0
    0 0 0
    1 1 0
]

sol722[20] = (U20, V20, W20)

# -------- i = 21 --------
U21 = Rational{Int}[
    1 0 0
    0 0 0
    0 0 0
]

V21 = Rational{Int}[
    0 1 1
    0 0 0
    0 0 -1
]

W21 = Rational{Int}[
    0 0 0
    0 0 0
    1 1 -1
]

sol722[21] = (U21, V21, W21)

# -------- i = 22 --------
U22 = Rational{Int}[
    0 0 0
    1 1 0
    0 0 0
]

V22 = Rational{Int}[
    0 1 0
    0 0 0
    0 0 0
]

W22 = Rational{Int}[
    0 0 0
    0 1 0
    0 -1 0
]

sol722[22] = (U22, V22, W22)

# -------- i = 23 --------
U23 = Rational{Int}[
    0 1 0
    0 0 0
    0 0 -1
]

V23 = Rational{Int}[
    0 0 0
    1 0 0
    0 0 0
]

W23 = Rational{Int}[
    1 0 0
    0 0 0
    0 0 0
]

sol722[23] = (U23, V23, W23)

# %%
# T=zeros(Rational{Int}, 27, 27)
# for i in 1:23
#     T = T + kron(sol722[i][1], sol722[i][2], sol722[i][3])
# end
# T

# %%
# mm=3; nn=3; pp=3;

# indices = [(i, j, k) for i in 1:mm for j in 1:nn for k in 1:pp]

# tenset=[]

# for (i, j, k) in indices
#     matrix = zeros(Int, mm, nn)
#     matrix[i,j] = 1
#     matrix1 = matrix
#     matrix = zeros(Int, nn, pp)
#     matrix[j,k] = 1
#     matrix2 = matrix
#     matrix = zeros(Int, pp, mm)
#     matrix[k,i] = 1
#     matrix3 = matrix
#     tensor_product = kron(kron(matrix1, matrix2), matrix3)
#     push!(tenset, tensor_product)
# end
# T1 = sum(tenset)

# %%
#using LinearAlgebra

# %%
#norm(T-T1)
